# %% [markdown]
# The aim of this project is to clean the data and analyze the included used car listings.

# %% [markdown]
# # Introduction

# %%
import numpy as np
import pandas as pd

autos = pd.read_csv(r"C:\Users\Administrator\Desktop\dataquest projects\autos.csv", encoding='Latin-1')

# %%
autos
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# 8       2016-04-04 23:42:13
# 9       2016-03-17 10:53:50
# 10      2016-03-26 19:54:18
# 11      2016-04-07 10:06:22
# 12      2016-03-15 22:49:09
# 13      2016-03-21 21:37:40
# 14      2016-03-21 12:57:01
# 15      2016-03-11 21:39:15
# 16      2016-04-01 12:46:46
# 17      2016-03-20 10:25:19
# 18      2016-03-23 15:48:05
# 19      2016-04-01 22:55:47
# 20      2016-04-01 19:56:48
# 21      2016-03-27 11:38:00
# 22      2016-03-23 14:52:51
# 23      2016-03-12 19:43:07
# 24      2016-03-13 20:40:49
# 25      2016-03-18 21:44:09
# 26      2016-03-10 19:38:18
# 27      2016-03-07 12:51:23
# 28      2016-03-09 11:56:38
# 29      2016-03-08 19:55:19
# ...                     ...
# 371498  2016-03-11 15:50:38
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
# dateCrawled            371528 non-null object
# name                   371528 non-null object
# seller                 371528 non-null object
# offerType              371528 non-null object
# price                  371528 non-null int64
# abtest                 371528 non-null object
# vehicleType            333659 non-null object
# yearOfRegistration     371528 non-null int64
# gearbox                351319 non-null object
# powerPS                371528 non-null int64
# model                  351044 non-null object
# kilometer              371528 non-null int64
# monthOfRegistration    371528 non-null int64
# fuelType               338142 non-null object
# brand                  371528 non-null object
# notRepairedDamage      299468 non-null object
# dateCreated            371528 non-null object
# nrOfPictures           371528 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %% [markdown]
# # Cleaning Column Names

# %% [markdown]
# From the work we did in the last screen, we can make the following observations:
#
# - The dataset contains 20 columns, most of which are strings.
# - Some columns have null values, but none have more than ~20% null values.
# - The column names use camelcase instead of Python's preferred snakecase, which means we can't just replace spaces with underscores.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename({"yearOfRegistration":"registration_year"}, axis=1, inplace=True)
autos.rename({"monthOfRegistration":"registration_month"}, inplace=True, axis=1)
autos.rename({"notRepairedDamage":"unrepaired_damage"}, inplace=True, axis=1)
autos.rename({"dateCreated":"ad_created"}, inplace=True, axis=1)

autos_lower = []
for c in autos.columns:
    abd = c.lower()
    autos_lower.append(abd)
    
autos.columns = autos_lower

# %%
autos.columns
# Out:
# Index(['datecrawled', 'name', 'seller', 'offertype', 'price', 'abtest',
#        'vehicletype', 'registration_year', 'gearbox', 'powerps', 'model',
#        'kilometer', 'registration_month', 'fueltype', 'brand',
#        'unrepaired_damage', 'ad_created', 'nrofpictures', 'postalcode',
#        'lastseen'],
#       dtype='object')

# %%
autos.head()
# Out:
#            datecrawled                            name  seller offertype  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicletype  registration_year    gearbox  powerps  model  \
# 0    480   test         NaN               1993    manuell        0   golf
# 1  18300   test       coupe               2011    manuell      190    NaN
# 2   9800   test         suv               2004  automatik      163  grand
# 3   1500   test  kleinwagen               2001    manuell       75   golf
# 4   3600   test  kleinwagen               2008    manuell       69  fabia
#
#    kilometer  registration_month fueltype       brand unrepaired_damage  \
# ...

# %% [markdown]
# # Initial Exploration and Cleaning

# %%
autos.rename({"nrofpictures":"num_photos"}, inplace=True, axis=1)

autos.describe(include='all')
# Out:
#                 datecrawled         name  seller offertype         price  \
# count                371528       371528  371528    371528  3.715280e+05
# unique               280500       233531       2         2           NaN
# top     2016-03-24 14:49:47  Ford_Fiesta  privat   Angebot           NaN
# freq                      7          657  371525    371516           NaN
# mean                    NaN          NaN     NaN       NaN  1.729514e+04
# std                     NaN          NaN     NaN       NaN  3.587954e+06
# min                     NaN          NaN     NaN       NaN  0.000000e+00
# 25%                     NaN          NaN     NaN       NaN  1.150000e+03
# 50%                     NaN          NaN     NaN       NaN  2.950000e+03
# 75%                     NaN          NaN     NaN       NaN  7.200000e+03
# max                     NaN          NaN     NaN       NaN  2.147484e+09
#
#         abtest vehicletype  registration_year  gearbox        powerps   model  \
# ...

# %% [markdown]
# We have learned that most of the columns are text value. However, the column "num_photos" looks odd since all values equal to 0.

# %%
autos["num_photos"].value_counts()
# Out:
# 0    371528
# Name: num_photos, dtype: int64

# %% [markdown]
# We will drop off this column and also "seller" and "offertype" since they mostly have only 1 value

# %%
autos.drop(["seller", "offertype", "num_photos"], axis=1)
# Out:
#                 datecrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# 8       2016-04-04 23:42:13
# 9       2016-03-17 10:53:50
# 10      2016-03-26 19:54:18
# 11      2016-04-07 10:06:22
# 12      2016-03-15 22:49:09
# 13      2016-03-21 21:37:40
# 14      2016-03-21 12:57:01
# 15      2016-03-11 21:39:15
# 16      2016-04-01 12:46:46
# 17      2016-03-20 10:25:19
# 18      2016-03-23 15:48:05
# 19      2016-04-01 22:55:47
# 20      2016-04-01 19:56:48
# 21      2016-03-27 11:38:00
# 22      2016-03-23 14:52:51
# 23      2016-03-12 19:43:07
# 24      2016-03-13 20:40:49
# 25      2016-03-18 21:44:09
# 26      2016-03-10 19:38:18
# 27      2016-03-07 12:51:23
# 28      2016-03-09 11:56:38
# 29      2016-03-08 19:55:19
# ...                     ...
# 371498  2016-03-11 15:50:38
# ...

# %% [markdown]
# # Exploring the Odometer and Price Columns

# %%
autos['price'].shape
# Out:
# (371528,)

# %%
autos['kilometer'].shape
# Out:
# (371528,)

# %%
autos['price'].describe()
# Out:
# count    3.715280e+05
# mean     1.729514e+04
# std      3.587954e+06
# min      0.000000e+00
# 25%      1.150000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      2.147484e+09
# Name: price, dtype: float64

# %%
autos['price'].value_counts().sort_index(ascending=False)
# Out:
# 2147483647        1
# 99999999         15
# 99000000          1
# 74185296          1
# 32545461          1
# 27322222          1
# 14000500          1
# 12345678          9
# 11111111         10
# 10010011          1
# 10000000          8
# 9999999           3
# 3895000           1
# 3890000           1
# 2995000           1
# 2795000           1
# 1600000           2
# 1300000           1
# 1250000           2
# 1234566           1
# 1111111           2
# 1010010           1
# 1000000           5
# 999999           13
# 999990            1
# 911911            1
# 849000            1
# 820000            1
# 780000            1
# 745000            2
#               ...
# 35               18
# 33                1
# 32                1
# 30               55
# 29                2
# 27                1
# 26                1
# 25               33
# 24                1
# 21                1
# 20               51
# 19                3
# 18                3
# 17                5
# ...

# %% [markdown]
# As a research on ebay, the cheapest price for the car is 2500 and the most expensive one is sold at 2,500,000. So, we are going to remove rows where "price" is outside of that range

# %%
autos = autos[autos["price"].between(2500, 2500000)]

# %%
autos["price"].value_counts().sort_index(ascending=False)
# Out:
# 1600000       2
# 1300000       1
# 1250000       2
# 1234566       1
# 1111111       2
# 1010010       1
# 1000000       5
# 999999       13
# 999990        1
# 911911        1
# 849000        1
# 820000        1
# 780000        1
# 745000        2
# 725000        1
# 700000        1
# 650000        1
# 619000        1
# 600000        2
# 599000        1
# 585000        1
# 579000        1
# 517895        1
# 500000        2
# 488997        1
# 487000        1
# 485000        1
# 466000        1
# 445000        1
# 440000        1
#            ...
# 2625          1
# 2620          1
# 2610          1
# 2601          1
# 2600       1717
# 2599        335
# 2598          2
# 2595          3
# 2590        174
# 2589          4
# 2580         15
# 2579          1
# 2575          2
# 2570          4
# 2569          1
# 2565          1
# 2560          4
# 2555         54
# 2550        477
# 2549         14
# 2544          1
# 2540          4
# 2530          5
# 2525          2
# ...

# %%
autos['kilometer'].value_counts()
# Out:
# 150000    106805
# 125000     24230
# 100000     11304
# 90000       9710
# 80000       8990
# 70000       8396
# 60000       7750
# 50000       7008
# 40000       5994
# 30000       5383
# 20000       4684
# 5000        2511
# 10000       1662
# Name: kilometer, dtype: int64

# %% [markdown]
# We can see that the values in this field are rounded, which might indicate that sellers had to choose from pre-set options for this field. Additionally, there are more high mileage than low mileage vehicles.

# %% [markdown]
# # Exploring the Date columns

# %% [markdown]
# There are 5 columns that should represent date values. Some of these columns were created by the crawler, some came from the website itself. We can differentiate by referring to the data dictionary:
# - `date_crawled`: added by the crawler
# - `last_seen`: added by the crawler
# - `ad_created`: from the website
# - `registration_month`: from the website
# - `registration_year`: from the website

# %%
autos['datecrawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.026225
# 2016-03-06    0.014881
# 2016-03-07    0.035108
# 2016-03-08    0.032163
# 2016-03-09    0.032936
# 2016-03-10    0.031689
# 2016-03-11    0.032359
# 2016-03-12    0.036566
# 2016-03-13    0.016808
# 2016-03-14    0.036536
# 2016-03-15    0.032041
# 2016-03-16    0.029174
# 2016-03-17    0.030808
# 2016-03-18    0.013022
# 2016-03-19    0.035039
# 2016-03-20    0.037153
# 2016-03-21    0.034692
# 2016-03-22    0.031444
# 2016-03-23    0.031586
# 2016-03-24    0.030016
# 2016-03-25    0.033239
# 2016-03-26    0.032789
# 2016-03-27    0.031307
# 2016-03-28    0.035979
# 2016-03-29    0.033758
# 2016-03-30    0.032970
# 2016-03-31    0.031498
# 2016-04-01    0.034951
# 2016-04-02    0.036453
# 2016-04-03    0.040719
# 2016-04-04    0.038464
# 2016-04-05    0.012718
# 2016-04-06    0.003273
# 2016-04-07    0.001639
# Name: datecrawled, dtype: float64

# %% [markdown]
# Looks like the site was crawled daily over roughly a one month period in March and April 2016. The distribution of listings crawled on each day is roughly uniform.

# %%
autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2014-03-10    0.000005
# 2015-03-20    0.000005
# 2015-06-11    0.000005
# 2015-06-18    0.000005
# 2015-08-07    0.000005
# 2015-08-10    0.000005
# 2015-09-09    0.000005
# 2015-10-14    0.000005
# 2015-11-02    0.000005
# 2015-11-08    0.000005
# 2015-11-10    0.000005
# 2015-11-12    0.000005
# 2015-11-13    0.000005
# 2015-11-17    0.000005
# 2015-11-23    0.000010
# 1997    0.007741
# 1998    0.012462
# 1999    0.018559
# 2000    0.024881
# 2001    0.033942
# 2002    0.041698
# 2003    0.053813
# 2004    0.068384
# 2005    0.083415
# 2006    0.088998
# 2007    0.081477
# 2008    0.076335
# 2009    0.074368
# 2010    0.059464
# ...

# %% [markdown]
# It appears that most vehicles were registered in the past 20 years

# %% [markdown]
# # Exploring Price by Brand

# %%
print(autos['brand'].unique())
# Out:
# ['audi' 'jeep' 'skoda' 'ford' 'volkswagen' 'nissan' 'bmw' 'opel' 'citroen'
#  'honda' 'mercedes_benz' 'mini' 'smart' 'volvo' 'renault' 'hyundai'
#  'alfa_romeo' 'kia' 'seat' 'subaru' 'porsche' 'mitsubishi' 'peugeot'
#  'fiat' 'mazda' 'toyota' 'chevrolet' 'sonstige_autos' 'dacia' 'chrysler'
#  'jaguar' 'suzuki' 'rover' 'saab' 'land_rover' 'lancia' 'trabant' 'lada'
#  'daihatsu' 'daewoo']

# %%
autos['brand'].value_counts()
# Out:
# volkswagen        43170
# bmw               28922
# mercedes_benz     25138
# audi              23252
# opel              14346
# ford              10073
# renault            5057
# peugeot            5031
# skoda              4191
# seat               3605
# fiat               3582
# mini               3295
# toyota             3246
# smart              2982
# mazda              2757
# citroen            2585
# sonstige_autos     2403
# hyundai            2341
# nissan             2243
# porsche            2112
# volvo              1688
# kia                1585
# honda              1340
# suzuki             1291
# chevrolet          1291
# mitsubishi         1176
# alfa_romeo         1102
# dacia               735
# jeep                699
# land_rover          687
# chrysler            679
# jaguar              515
# subaru              330
# saab                264
# daihatsu            180
# lancia              143
# trabant             131
# lada                124
# ...

# %% [markdown]
# German facturers have 4 out of top 5 brands, represent almost 50% of the listings. Volkswagen is by far the most popular manufacture since its sales are almost doubled than the 2nd ranking which is bmw.
#
# Some manufacturers have small percentage so we will limite our analysis by only keeping those who have more than 5%

# %%
brand_counts = autos['brand'].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > 0.05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'mercedes_benz', 'audi', 'opel'], dtype='object')

# %%
price_per_brand = {}

for b in common_brands:
    brand = autos[autos["brand"] == b]
    mean_price = brand["price"].mean()
    price_per_brand[b] = int(mean_price)
    
price_per_brand
# Out:
# {'volkswagen': 8663,
#  'bmw': 11011,
#  'mercedes_benz': 11201,
#  'audi': 11952,
#  'opel': 6382}

# %% [markdown]
# As per our analysis, BMW, Mercedes Benz and Audi are the most expensive car while Opel is the most affordable. Volkswagen is in between those 2 groups and this could explain why Volks are the most popular manufacturers since clients probably think they have the advantages of both expensive and inexpensive groups.

# %% [markdown]
# #   Storing Aggregate Data in a DataFrame

# %%
mean_price = pd.Series(price_per_brand)
pd.DataFrame(mean_price, columns=['mean_price'])
# Out:
#                mean_price
# volkswagen           8663
# bmw                 11011
# mercedes_benz       11201
# audi                11952
# opel                 6382

# %%
mileage_per_brand = {}

for b in common_brands:
    brand = autos[autos["brand"] == b]
    mean_mileage = brand["kilometer"].mean()
    mileage_per_brand[b] = int(mean_mileage)
    
mean_mileage = pd.Series(mileage_per_brand).sort_values(ascending=False)
mean_price = pd.Series(price_per_brand).sort_values(ascending=False)

table = pd.DataFrame(mean_mileage, columns=['mean_mileage'])

# %%
table['mean_price'] = mean_price

table
# Out:
#                mean_mileage  mean_price
# bmw                  129207       11011
# mercedes_benz        126081       11201
# audi                 124265       11952
# volkswagen           118799        8663
# opel                 112284        6382

# %% [markdown]
# The range of car mileages does not vary as much as the prices do by brand, instead all falling within 10% for the top brands. There is a slight trend to the more expensive vehicles having higher mileage, with the less expensive vehicles having lower mileage.
